# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import pickle

# %% [markdown]
# ### Import Datasets

# %%
hot100 = pd.read_csv("/Users/robertkammerer/Ironhack/06_Week/Labs_Week_6/Spotify_Project/Data/hot100features.csv")
nothot = pd.read_csv("/Users/robertkammerer/Ironhack/06_Week/Labs_Week_6/Spotify_Project/Data/nothotfeatures2.csv")
hot100['hot/not']="hot"
nothot['hot/not']="not"

# %%
display(hot100.head())
display(nothot.head())
print(hot100.shape)
print(nothot.shape)
# Out:
#                        track              artist  \
# 0                 Heat Waves       Glass Animals
# 1  We Don't Talk About Bruno  Lin-Manuel Miranda
# 2              Super Gremlin         Sniper Gang
# 3                    abcdefu               GAYLE
# 4  STAY (with Justin Bieber)       The Kid LAROI
#
#                                                album                      id  \
# 0                                          Dreamland  3USxtqRwSYz57Ewm6wWRMp
# 1       Encanto (Original Motion Picture Soundtrack)  52xJxFP6TqMuO4Yt0eOkMz
# 2  Sniper Gang Presents Syko Bob & Snapkatt: Nigh...  4A8cWXxKfIL3lAyUDzXbCF
# 3                                            abcdefu  4fouWK6XVHhzl78KzQ1UjL
# 4                          STAY (with Justin Bieber)  5HCyWlXZPP0y6Gqq8TgA20
#
#    danceability  energy  key  loudness  mode  speechiness  instrumentalness  \
# 0         0.761   0.525   11    -6.900     1       0.0944          0.000007
# ...

# %%
# Concat the data

allsongs = pd.concat([hot100, nothot],axis=0)
display(allsongs.head())
allsongs.shape
allsongs=allsongs.reset_index()
# Out:
#                        track              artist  \
# 0                 Heat Waves       Glass Animals
# 1  We Don't Talk About Bruno  Lin-Manuel Miranda
# 2              Super Gremlin         Sniper Gang
# 3                    abcdefu               GAYLE
# 4  STAY (with Justin Bieber)       The Kid LAROI
#
#                                                album                      id  \
# 0                                          Dreamland  3USxtqRwSYz57Ewm6wWRMp
# 1       Encanto (Original Motion Picture Soundtrack)  52xJxFP6TqMuO4Yt0eOkMz
# 2  Sniper Gang Presents Syko Bob & Snapkatt: Nigh...  4A8cWXxKfIL3lAyUDzXbCF
# 3                                            abcdefu  4fouWK6XVHhzl78KzQ1UjL
# 4                          STAY (with Justin Bieber)  5HCyWlXZPP0y6Gqq8TgA20
#
#    danceability  energy  key  loudness  mode  speechiness  instrumentalness  \
# 0         0.761   0.525   11    -6.900     1       0.0944          0.000007
# ...

# %%
features = allsongs[['danceability','energy','key','loudness','mode','speechiness','instrumentalness','liveness','valence','tempo']]
print(features.shape)
features
# Out:
# (3204, 10)
#       danceability  energy  key  loudness  mode  speechiness  \
# 0            0.761  0.5250   11    -6.900     1       0.0944
# 1            0.577  0.4500    0    -8.516     0       0.0834
# 2            0.825  0.4140    2    -6.634     1       0.1440
# 3            0.695  0.5400    4    -5.692     1       0.0493
# 4            0.591  0.7640    1    -5.484     1       0.0483
# ...            ...     ...  ...       ...   ...          ...
# 3199         0.343  0.0342    8   -25.591     1       0.0406
# 3200         0.382  0.0499    2   -25.262     1       0.0548
# 3201         0.151  0.0639   11   -24.404     0       0.0439
# 3202         0.226  0.0938    0   -26.871     0       0.1000
# 3203         0.199  0.0677    0   -20.879     1       0.0390
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000007    0.0921   0.5310   80.870
# 1             0.000000    0.1110   0.8300  205.863
# 2             0.000000    0.3570   0.1060   72.993
# ...

# %%
features.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   3204.000000  3204.000000  3204.000000  3204.000000  3204.000000
# mean       0.634572     0.687873     5.296504    -7.230050     0.598627
# std        0.164440     0.180806     3.672187     3.376599     0.490253
# min        0.068500     0.005010     0.000000   -37.841000     0.000000
# 25%        0.532000     0.578000     2.000000    -8.571750     0.000000
# 50%        0.652000     0.708000     5.000000    -6.635500     1.000000
# 75%        0.757000     0.823000     9.000000    -5.154750     1.000000
# max        0.979000     0.999000    11.000000     1.342000     1.000000
#
#        speechiness  instrumentalness     liveness      valence        tempo
# count   3204.00000       3204.000000  3204.000000  3204.000000  3204.000000
# mean       0.16852          0.077158     0.193985     0.528539   118.118807
# std        0.14557          0.222816     0.157314     0.229350    30.317738
# ...

# %%
scaler = StandardScaler()
scaler.fit(features) 
features_scaled = scaler.transform(features)
filename = "/Users/robertkammerer/Ironhack/06_Week/Labs_Week_6/Spotify_Project/Classification/pickle/scaler.pickle"
with open(filename, "wb") as f:
    pickle.dump(scaler,f)
features_scaled_df = pd.DataFrame(features_scaled, columns = features.columns)
display(features.head())
display(features_scaled_df.head())
# Out:
#    danceability  energy  key  loudness  mode  speechiness  instrumentalness  \
# 0         0.761   0.525   11    -6.900     1       0.0944          0.000007
# 1         0.577   0.450    0    -8.516     0       0.0834          0.000000
# 2         0.825   0.414    2    -6.634     1       0.1440          0.000000
# 3         0.695   0.540    4    -5.692     1       0.0493          0.000000
# 4         0.591   0.764    1    -5.484     1       0.0483          0.000000
#
#    liveness  valence    tempo
# 0    0.0921    0.531   80.870
# 1    0.1110    0.830  205.863
# 2    0.3570    0.106   72.993
# 3    0.3670    0.415  121.932
# 4    0.1030    0.478  169.928
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      0.768963 -0.900955  1.553403  0.097762  0.818835    -0.509249
# 1     -0.350161 -1.315829 -1.442555 -0.380901 -1.221248    -0.584826
# 2      1.158223 -1.514969 -0.897835  0.176551  0.818835    -0.168467
# ...

# %%
features_scaled_df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  3.204000e+03  3.204000e+03  3.204000e+03  3.204000e+03  3.204000e+03
# mean  -2.777637e-16 -3.696585e-16  1.070028e-16  5.516464e-17 -6.875482e-16
# std    1.000156e+00  1.000156e+00  1.000156e+00  1.000156e+00  1.000156e+00
# min   -3.442957e+00 -3.777359e+00 -1.442555e+00 -9.067032e+00 -1.221248e+00
# 25%   -6.238601e-01 -6.077775e-01 -8.978352e-01 -3.974146e-01 -1.221248e+00
# 50%    1.060033e-01  1.113374e-01 -8.075587e-02  1.761070e-01  8.188346e-01
# 75%    7.446338e-01  7.474775e-01  1.008683e+00  6.147085e-01  8.188346e-01
# max    2.094881e+00  1.721048e+00  1.553403e+00  2.539060e+00  8.188346e-01
#
#         speechiness  instrumentalness      liveness       valence  \
# count  3.204000e+03      3.204000e+03  3.204000e+03  3.204000e+03
# mean  -4.171653e-16      1.400738e-15 -8.423696e-17 -5.752092e-18
# std    1.000156e+00      1.000156e+00  1.000156e+00  1.000156e+00
# ...

# %%
K = range(2, 20)
inertia = []
silhouette = []

for k in K:
    print("Training a K-Means model with {} neighbours! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(features_scaled_df)
    filename = "/Users/robertkammerer/Ironhack/06_Week/Labs_Week_6/Spotify_Project/Classification/pickle/kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    inertia.append(kmeans.inertia_)
    silhouette.append(silhouette_score(features_scaled_df, kmeans.predict(features_scaled_df)))


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1,2,figsize=(16,8))
ax[0].plot(K, inertia, 'bx-')
ax[0].set_xlabel('k')
ax[0].set_ylabel('inertia')
ax[0].set_xticks(np.arange(min(K), max(K)+1, 1.0))
ax[0].set_title('Elbow Method showing the optimal k')
ax[1].plot(K, silhouette, 'bx-')
ax[1].set_xlabel('k')
ax[1].set_ylabel('silhouette score')
ax[1].set_xticks(np.arange(min(K), max(K)+1, 1.0))
ax[1].set_title('Silhouette Method showing the optimal k')
# Out:
# Training a K-Means model with 2 neighbours!
#
# Training a K-Means model with 3 neighbours!
#
# Training a K-Means model with 4 neighbours!
#
# Training a K-Means model with 5 neighbours!
#
# Training a K-Means model with 6 neighbours!
#
# Training a K-Means model with 7 neighbours!
#
# Training a K-Means model with 8 neighbours!
#
# Training a K-Means model with 9 neighbours!
#
# Training a K-Means model with 10 neighbours!
#
# Training a K-Means model with 11 neighbours!
#
# Training a K-Means model with 12 neighbours!
#
# Training a K-Means model with 13 neighbours!
#
# Training a K-Means model with 14 neighbours!
#
# Training a K-Means model with 15 neighbours!
#
# Training a K-Means model with 16 neighbours!
#
# Training a K-Means model with 17 neighbours!
#
# Training a K-Means model with 18 neighbours!
#
# Training a K-Means model with 19 neighbours!
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %% [markdown]
# ### Load Scaler and best model

# %%
def load(filename = "filename.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
    except FileNotFoundError: 
        print("File not found!")

# %%
scaler2 = load("/Users/robertkammerer/Ironhack/06_Week/Labs_Week_6/Spotify_Project/Classification/pickle/scaler.pickle")
scaler2
# Out:
# StandardScaler()

# %%
best_model = load("/Users/robertkammerer/Ironhack/06_Week/Labs_Week_6/Spotify_Project/Classification/pickle/kmeans_10.pickle")

# %%
clusters = best_model.predict(features_scaled_df)
pd.Series(clusters).value_counts().sort_index()
allsongs_final=allsongs.copy()
allsongs_final["cluster"] = clusters

# %%
allsongs_final
# Out:
#       index                                              track  \
# 0         0                                         Heat Waves
# 1         1                          We Don't Talk About Bruno
# 2         2                                      Super Gremlin
# 3         3                                            abcdefu
# 4         4                          STAY (with Justin Bieber)
# ...     ...                                                ...
# 3199   3104  Liebestraume, S541/R211 : No. 3: Nocturne in A...
# 3200   3105                        Fantasia in D Minor, K. 397
# 3201   3106      Scheherazade: The Tale of the Kalendar Prince
# 3202   3107  Symphonie fantastique: V. Dream of a Witches' ...
# 3203   3108  Romeo and Juliet, Op. 64 / Act 1: Dance Of The...
#
#                        artist  \
# 0               Glass Animals
# 1          Lin-Manuel Miranda
# 2                 Sniper Gang
# 3                       GAYLE
# 4               The Kid LAROI
# ...

# %%
#allsongs_final['cluster'].value_counts()

# %%
allsongs_final.to_csv("/Users/robertkammerer/Ironhack/06_Week/Labs_Week_6/Spotify_Project/Data/clustered_songdatabase_10d_10.csv",index=False)
